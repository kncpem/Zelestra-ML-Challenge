# %%
import pandas as pd
import numpy as np

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test.describe()
# Out:
#                 id   temperature    irradiance     panel_age  \
# count  12000.00000  11418.000000  11385.000000  11393.000000
# mean    5999.50000     25.146375    503.680996     17.473594
# std     3464.24595     12.278231    250.888332     10.095197
# min        0.00000      0.000000   -564.252322      0.013553
# 25%     2999.75000     16.768567    334.595229      8.612788
# 50%     5999.50000     24.887335    505.037516     17.402885
# 75%     8999.25000     33.143483    671.762708     26.134488
# max    11999.00000    145.879677   1420.627376     34.989441
#
#        maintenance_count  soiling_ratio       voltage       current  \
# count       11391.000000   11390.000000  11453.000000  11413.000000
# mean            3.991836       0.700468     16.520001      1.708212
# std             1.995215       0.172455     18.402507      1.147612
# min             0.000000       0.400042      0.000000      0.000065
# 25%             3.000000       0.553302      0.000000      0.767381
# 50%             4.000000       0.697455     12.966453      1.565075
# 75%             5.000000       0.850781     27.020573      2.459744
# max            13.000000       0.999976    417.682763      7.256391
#
#        module_temperature  cloud_coverage
# count        11420.000000    11418.000000
# mean            30.038138       51.324166
# std             12.216873       45.723208
# min              0.000000        0.001065
# 25%             21.478909       25.079720
# 50%             29.952897       49.780073
# 75%             38.315531       75.191692
# max             65.000000     1000.000000

# %%
#replaces all values less than 0 with 0
df_test['irradiance'] = df_test['irradiance'].clip(lower=0)

# %%
df_test['error_code'] = df_test['error_code'].fillna('missing')
df_test['installation_type'] = df_test['installation_type'].fillna('missing')

# %%
cols_to_convert = ['humidity', 'wind_speed', 'pressure']

# Remove non-numeric characters if any, then convert to float
for col in cols_to_convert:
    df_test[col] = pd.to_numeric(df_test[col], errors='coerce')

# %%
filtered_df = df_test.copy()

# %%
filtered_df[filtered_df.select_dtypes(include='number').columns] = filtered_df.select_dtypes(include='number').fillna(filtered_df.median(numeric_only=True))

# %%
## drop the id ccolumn
ids = filtered_df['id']
filtered_df = filtered_df.drop(columns = ['id'])

# %%
# Specify the low‐cardinality categorical columns to one‐hot encode
cols_to_encode = ['string_id', 'error_code', 'installation_type']

# Perform one‐hot encoding using pandas.get_dummies
filtered_df_encoded = pd.get_dummies(
    filtered_df,
    columns=cols_to_encode,
    prefix=cols_to_encode,
    drop_first=False  # keep all dummy columns (you can set True to avoid multicollinearity)
)

# View the first few rows of the encoded DataFrame
filtered_df_encoded.head()
# Out:
#    temperature  irradiance   humidity  panel_age  maintenance_count  \
# 0    17.618379   85.449838  90.815423  13.910963                6.0
# 1    34.826323  722.801748  20.982993  20.916528                4.0
# 2    33.776934  485.491998  55.614050   1.446962                3.0
# 3    18.584189  350.022720  49.044766  18.810133                5.0
# 4    43.044908  437.295622   8.761571  17.402885                8.0
#
#    soiling_ratio    voltage   current  module_temperature  cloud_coverage  \
# 0       0.889765   6.370396  0.069101           19.517274       33.509889
# 1       0.590372  30.095867  1.713852           37.421443       32.327060
# 2       0.611425  28.424430  1.696936           32.147763       69.613333
# 3       0.697455   7.848038  0.787188           25.734118       42.862760
# 4       0.564938  12.300717  1.867620           29.952897       51.025763
#
#    ...  string_id_C3  string_id_D4  error_code_E00  error_code_E01  \
# 0  ...          True         False           False            True
# 1  ...         False          True            True           False
# 2  ...         False          True           False            True
# 3  ...          True         False           False           False
# 4  ...         False         False           False           False
#
#    error_code_E02  error_code_missing  installation_type_dual-axis  \
# 0           False               False                        False
# 1           False               False                        False
# 2           False               False                         True
# 3            True               False                         True
# 4           False                True                        False
#
#    installation_type_fixed  installation_type_missing  \
# 0                    False                      False
# 1                    False                       True
# 2                    False                      False
# 3                    False                      False
# 4                     True                      False
#
#    installation_type_tracking
# 0                        True
# 1                       False
# 2                       False
# 3                       False
# 4                       False
#
# [5 rows x 24 columns]

# %%
# Add new derived features
filtered_df_encoded['power'] = filtered_df_encoded['voltage'] * filtered_df_encoded['current']
filtered_df_encoded['temperature_delta'] = filtered_df_encoded['module_temperature'] - filtered_df_encoded['temperature']
filtered_df_encoded['maintenance_impact'] = filtered_df_encoded['panel_age'] / (filtered_df_encoded['maintenance_count'] + 1)
filtered_df_encoded['cloud_impact'] = filtered_df_encoded['cloud_coverage'] * filtered_df_encoded['irradiance']

# %%
import pickle

model_path = "C:\Local Disk F\ML\Zelestra ML Challenge\Models\lightgbm_model.pkl"

with open(model_path, 'rb') as file:
    loaded_model = pickle.load(file)

# %%
predictions = loaded_model.predict(filtered_df_encoded)

# %%
submission_df = pd.DataFrame({
    'id': ids,
    'efficiency': predictions
})

# %%
import os, re

path = r'C:\Local Disk F\ML\Zelestra ML Challenge\Submission files'
files = [int(re.findall(r'\d+', f)[0]) for f in os.listdir(path) if re.match(r'sub\d+\.csv$', f)]
next_ver = max(files, default=0) + 1
submission_df.to_csv(os.path.join(path, f'sub{next_ver}.csv'), index=False)
